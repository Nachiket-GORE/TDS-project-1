# %%
import requests
import csv
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
import pandas as pd

# GitHub API token and headers
#*********************************************************************************
GITHUB_TOKEN = ""      ############### PUT   YOUR   TOKEN      HERE ##############
CITY='Chicago'    ############### PUT   YOUR   CITY      HERE ##############
FOLLOWERS=100     ############### PUT   YOUR   FOLLOWERS      HERE ##############
HEADERS = {"Authorization": f"token {GITHUB_TOKEN}"}

# Helper function to clean up company names
def clean_company_name(company):
    return company.strip().lstrip('@').upper() if company else None

# Function to fetch users from the GitHub API
def fetch_users(city=CITY, min_followers=FOLLOWERS):
    users = []
    page = 1
    while True:
        url = f"https://api.github.com/search/users?q=location:{city}+followers:>{min_followers}&page={page}&per_page=100"
        response = requests.get(url, headers=HEADERS)
        data = response.json()

        if 'items' not in data or not data['items']:
            break  # Stop if no users found

        for user in data['items']:
            # Get full user info
            user_url = user['url']
            user_response = requests.get(user_url, headers=HEADERS)
            user_data = user_response.json()

            # Extract required fields
            users.append({
                'login': user_data['login'],
                'name': user_data['name'],
                'company': clean_company_name(user_data['company']),
                'location': user_data['location'],
                'email': user_data['email'],
                'hireable': user_data['hireable'],
                'bio': user_data['bio'],
                'public_repos': user_data['public_repos'],
                'followers': user_data['followers'],
                'following': user_data['following'],
                'created_at': user_data['created_at'],
            })

        page += 1
        time.sleep(1)  # To avoid hitting rate limits

    return users

# Function to fetch repositories for a user with a max limit of 500
def fetch_repositories(user_login, max_repos=500):
    repositories = []
    page = 1
    while len(repositories) < max_repos:
        url = f"https://api.github.com/users/{user_login}/repos?sort=pushed&per_page=100&page={page}"
        response = requests.get(url, headers=HEADERS)
        repo_data = response.json()

        if not repo_data:
            break

        for repo in repo_data[:max_repos - len(repositories)]:
            repositories.append({
                'login': user_login,
                'full_name': repo['full_name'],
                'created_at': repo['created_at'],
                'stargazers_count': repo['stargazers_count'],
                'watchers_count': repo['watchers_count'],
                'language': repo['language'],
                'has_projects': repo['has_projects'],
                'has_wiki': repo['has_wiki'],
                'license_name': repo['license']['key'] if repo['license'] else None,
            })

        if len(repo_data) < 100:
            break

        page += 1
        time.sleep(0.5)  # Minimal delay to avoid hitting rate limits

    return repositories

# Function to save data to CSV
def save_to_csv(data, filename):
    with open(filename, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=data[0].keys())
        writer.writeheader()
        writer.writerows(data)

def main():
    print("Fetching users...")
    users = fetch_users()
    save_to_csv(users, "users.csv")
    users_df = pd.read_csv('users.csv')

    # Check the data types and structure
    print(users_df.head())

    # Replace True/False with true/false in the hireable column
    users_df['hireable'] = users_df['hireable'].replace({True: 'true', False: 'false'})

    # Save the modified DataFrame back to the same CSV file
    users_df.to_csv('users.csv', index=False)

    # Check the data types and structure
    print(users_df.head())


    #print("Updated CSV file saved successfully.")
    print(f"Saved {len(users)} users to users.csv")

    print("Fetching repositories in parallel...")
    all_repositories = []

    # Use ThreadPoolExecutor to fetch repositories for multiple users concurrently
    with ThreadPoolExecutor(max_workers=5) as executor:
        futures = {executor.submit(fetch_repositories, user["login"]): user for user in users}
        for future in as_completed(futures):
            user = futures[future]
            try:
                user_repos = future.result()
                all_repositories.extend(user_repos)
                print(f"Fetched {len(user_repos)} repositories for user {user['login']}")
            except Exception as e:
                print(f"Error fetching repositories for {user['login']}: {e}")


    save_to_csv(all_repositories, "repositories.csv")
    repositories_df = pd.read_csv('repositories.csv')

    # Check the data types and structure
    print(repositories_df.head())

    # Replace True/False with true/false
    repositories_df['has_projects'] = repositories_df['has_projects'].replace({True: 'true', False: 'false'})
    repositories_df['has_wiki'] = repositories_df['has_wiki'].replace({True: 'true', False: 'false'})

    # Save the modified DataFrame back to the same CSV file
    repositories_df.to_csv('repositories.csv', index=False)

    # Check the data types and structure
    print(repositories_df.head())

    #print("Updated CSV file saved successfully.")
    print(f"Saved {len(all_repositories)} repositories to repositories.csv")

if __name__ == "__main__":
    main()
# Out:
# Fetching users...
#          login              name                     company     location  \
# 0     cassidoo  Cassidy Williams                      GITHUB  Chicago, IL
# 1     felangel     Felix Angelov               SHOREBIRDTECH      Chicago
# 2       dabeaz     David Beazley                 DABEAZ, LLC      Chicago
# 3  sstephenson    Sam Stephenson                         NaN      Chicago
# 4  mattgodbolt      Matt Godbolt  AQUATIC CAPITAL MANAGEMENT  Chicago, IL
#
#                   email hireable  \
# 0                   NaN      NaN
# 1  felangelov@gmail.com      NaN
# 2       dave@dabeaz.com      NaN
# 3          sam@sls.name      NaN
# 4      matt@godbolt.org      NaN
#
#                                                  bio  public_repos  followers  \
# 0            Making memes and dreams... and software           165      13382
# 1  software engineer by day, software engineer by...           125       8678
# 2  Author of the Python Essential Reference (Addi...            34       5181
# 3                                                NaN            24       3761
# 4  Compiler Explorer and jsbeeb creator, ex-Googl...            84       3398
#
#    following            created_at
# 0        102  2012-02-20T16:36:23Z
# 1         67  2014-09-22T02:35:58Z
# 2          0  2010-08-01T15:22:48Z
# 3          0  2008-03-08T22:17:24Z
# 4         97  2011-02-23T13:46:48Z
#          login              name                     company     location  \
# 0     cassidoo  Cassidy Williams                      GITHUB  Chicago, IL
# 1     felangel     Felix Angelov               SHOREBIRDTECH      Chicago
# 2       dabeaz     David Beazley                 DABEAZ, LLC      Chicago
# 3  sstephenson    Sam Stephenson                         NaN      Chicago
# 4  mattgodbolt      Matt Godbolt  AQUATIC CAPITAL MANAGEMENT  Chicago, IL
#
#                   email hireable  \
# 0                   NaN      NaN
# 1  felangelov@gmail.com      NaN
# 2       dave@dabeaz.com      NaN
# 3          sam@sls.name      NaN
# 4      matt@godbolt.org      NaN
#
#                                                  bio  public_repos  followers  \
# 0            Making memes and dreams... and software           165      13382
# 1  software engineer by day, software engineer by...           125       8678
# 2  Author of the Python Essential Reference (Addi...            34       5181
# 3                                                NaN            24       3761
# 4  Compiler Explorer and jsbeeb creator, ex-Googl...            84       3398
#
#    following            created_at
# 0        102  2012-02-20T16:36:23Z
# 1         67  2014-09-22T02:35:58Z
# 2          0  2010-08-01T15:22:48Z
# 3          0  2008-03-08T22:17:24Z
# 4         97  2011-02-23T13:46:48Z
# Saved 376 users to users.csv
# Fetching repositories in parallel...
# Fetched 34 repositories for user dabeaz
# Fetched 24 repositories for user sstephenson
# Fetched 84 repositories for user mattgodbolt
# Fetched 6 repositories for user adashofdata
# Fetched 125 repositories for user felangel
# Fetched 165 repositories for user cassidoo
# Fetched 104 repositories for user khan4019
# Fetched 143 repositories for user djspiewak
# Fetched 229 repositories for user logankilpatrick
# Fetched 147 repositories for user lexi-lambda
# Fetched 148 repositories for user rentzsch
# Fetched 242 repositories for user natemoo-re
# Fetched 113 repositories for user HFTrader
# Fetched 98 repositories for user jcs
# Fetched 205 repositories for user JimLiu
# Fetched 171 repositories for user jbranchaud
# Fetched 471 repositories for user eddelbuettel
# Fetched 193 repositories for user basecamp
# Fetched 66 repositories for user SciSharp
# Fetched 59 repositories for user davidteather
# Fetched 127 repositories for user johnpolacek
# Fetched 411 repositories for user neodigm
# Fetched 107 repositories for user dchelimsky
# Fetched 214 repositories for user joshdholtz
# Fetched 155 repositories for user jeremyckahn
# Fetched 155 repositories for user coreyhaines
# Fetched 22 repositories for user sksamuel
# Fetched 47 repositories for user hwayne
# Fetched 182 repositories for user harperreed
# Fetched 36 repositories for user sean-codes
# Fetched 42 repositories for user gjreda
# Fetched 215 repositories for user rharter
# Fetched 41 repositories for user djsime1
# Fetched 88 repositories for user jameslamb
# Fetched 136 repositories for user CoralineAda
# Fetched 2 repositories for user dabeaz-course
# Fetched 175 repositories for user leeoniya
# Fetched 26 repositories for user trek
# Fetched 61 repositories for user Valve
# Fetched 72 repositories for user catarak
# Fetched 181 repositories for user LadyKerr
# Fetched 219 repositories for user awatson1978
# Fetched 68 repositories for user ZeweiChu
# Fetched 46 repositories for user bitsondatadev
# Fetched 256 repositories for user lorenanicole
# Fetched 374 repositories for user dannguyen
# Fetched 179 repositories for user estrattonbailey
# Fetched 217 repositories for user peterpme
# Fetched 9 repositories for user jorgecoca
# Fetched 2 repositories for user bgardner
# Fetched 155 repositories for user phinze
# Fetched 69 repositories for user Templarian
# Fetched 31 repositories for user jamesturk
# Fetched 396 repositories for user scopatz
# Fetched 27 repositories for user an0
# Fetched 18 repositories for user kierisi
# Fetched 188 repositories for user lvh
# Fetched 14 repositories for user iSoron
# Fetched 45 repositories for user derekeder
# Fetched 29 repositories for user rachelbaker
# Fetched 177 repositories for user adriangb
# Fetched 7 repositories for user gk5885
# Fetched 98 repositories for user themeteorchef
# Fetched 34 repositories for user bwya77
# Fetched 30 repositories for user tqbf
# Fetched 10 repositories for user vehbiu
# Fetched 59 repositories for user mjskay
# Fetched 130 repositories for user kpdecker
# Fetched 76 repositories for user DashBarkHuss
# Fetched 36 repositories for user zigurous
# Fetched 16 repositories for user brandonleegit
# Fetched 243 repositories for user ELLIOTTCABLE
# Fetched 44 repositories for user rsese
# Fetched 23 repositories for user jarry-xiao
# Fetched 273 repositories for user carolynvs
# Fetched 31 repositories for user the-raspberry-pi-guy
# Fetched 274 repositories for user mapmeld
# Fetched 43 repositories for user ZWMiller
# Fetched 131 repositories for user boonebgorges
# Fetched 48 repositories for user matagus
# Fetched 12 repositories for user braverock
# Fetched 30 repositories for user stevespringett
# Fetched 60 repositories for user skwp
# Fetched 18 repositories for user jenmyers
# Fetched 500 repositories for user austinsonger
# Fetched 97 repositories for user MarkTechson
# Fetched 188 repositories for user saforem2
# Fetched 56 repositories for user Tedko
# Fetched 14 repositories for user loganmartintran
# Fetched 26 repositories for user justinbmeyer
# Fetched 77 repositories for user abedra
# Fetched 79 repositories for user trevorturk
# Fetched 8 repositories for user coolbeet
# Fetched 46 repositories for user srobbin
# Fetched 42 repositories for user timrwood
# Fetched 14 repositories for user shayhowe
# Fetched 213 repositories for user gar1t
# Fetched 49 repositories for user ksobon
# Fetched 110 repositories for user RandomFractals
# Fetched 26 repositories for user emilyriederer
# Fetched 74 repositories for user hugs
# Fetched 72 repositories for user karllhughes
# Fetched 60 repositories for user Oceania2018
# Fetched 16 repositories for user nickvourd
# Fetched 86 repositories for user reiddraper
# Fetched 55 repositories for user sorentwo
# Fetched 16 repositories for user XavierXiao
# Fetched 56 repositories for user ahinchman1
# Fetched 79 repositories for user stevenwanderski
# Fetched 463 repositories for user sabre1041
# Fetched 101 repositories for user JoeGermuska
# Fetched 4 repositories for user greensock
# Fetched 154 repositories for user tswast
# Fetched 31 repositories for user ExplorerFreda
# Fetched 89 repositories for user paulromano
# Fetched 218 repositories for user coddingtonbear
# Fetched 12 repositories for user rguthrie3
# Fetched 424 repositories for user jjhelmus
# Fetched 134 repositories for user alysivji
# Fetched 14 repositories for user CodePlatoon
# Fetched 65 repositories for user nbriz
# Fetched 176 repositories for user tedivm
# Fetched 89 repositories for user mrkurt
# Fetched 143 repositories for user FreedomWriter
# Fetched 56 repositories for user msfrisbie
# Fetched 42 repositories for user Daniel-McCarthy
# Fetched 101 repositories for user kadamwhite
# Fetched 124 repositories for user conorpp
# Fetched 33 repositories for user bartosz-lipinski
# Fetched 310 repositories for user MelSumner
# Fetched 58 repositories for user ivelasq
# Fetched 3 repositories for user jackdoyle
# Fetched 21 repositories for user rrag
# Fetched 74 repositories for user joshbirk
# Fetched 66 repositories for user pushcx
# Fetched 38 repositories for user drewolson
# Fetched 45 repositories for user ionelabrinza
# Fetched 73 repositories for user jamigibbs
# Fetched 68 repositories for user joemaddalone
# Fetched 90 repositories for user mager
# Fetched 154 repositories for user brandonwillard
# Fetched 12 repositories for user brianboyer
# Fetched 44 repositories for user mstruve
# Fetched 61 repositories for user brasic
# Fetched 47 repositories for user braintreeps
# Fetched 79 repositories for user k4rtik
# Fetched 65 repositories for user MarcosX
# Fetched 187 repositories for user jberger
# Fetched 157 repositories for user mikehostetler
# Fetched 13 repositories for user FormerLurker
# Fetched 39 repositories for user syngenta-digital
# Fetched 147 repositories for user mikewesthad
# Fetched 84 repositories for user jordanorelli
# Fetched 39 repositories for user dremin
# Fetched 40 repositories for user samanthamichele7
# Fetched 8 repositories for user jdingel
# Fetched 96 repositories for user arsho
# Fetched 72 repositories for user keeleysam
# Fetched 30 repositories for user Athlon1600
# Fetched 46 repositories for user rcalix1
# Fetched 13 repositories for user Shawn-Shan
# Fetched 84 repositories for user johnwinans
# Fetched 43 repositories for user wesleywiser
# Fetched 109 repositories for user tighten
# Fetched 134 repositories for user dhermes
# Fetched 204 repositories for user ryan-haskell
# Fetched 29 repositories for user itsjafer
# Fetched 92 repositories for user simonpcouch
# Fetched 7 repositories for user aekaplan
# Fetched 232 repositories for user luisibanez
# Fetched 57 repositories for user tlamadon
# Fetched 24 repositories for user Vadman97
# Fetched 42 repositories for user luizaandrade
# Fetched 357 repositories for user farrukh90
# Fetched 40 repositories for user noootown
# Fetched 135 repositories for user gregwebs
# Fetched 196 repositories for user seanchen1991
# Fetched 67 repositories for user ReidCarlberg
# Fetched 74 repositories for user cdfuller
# Fetched 62 repositories for user fsadykov
# Fetched 380 repositories for user bf4
# Fetched 0 repositories for user masterysystems
# Fetched 95 repositories for user eaton
# Fetched 96 repositories for user zombor
# Fetched 128 repositories for user chelseatroy
# Fetched 63 repositories for user JSH32
# Fetched 60 repositories for user ricokahler
# Fetched 28 repositories for user wseemann
# Fetched 68 repositories for user karlstolley
# Fetched 231 repositories for user dkarter
# Fetched 43 repositories for user bhgames
# Fetched 13 repositories for user dziganto
# Fetched 47 repositories for user codersquid
# Fetched 99 repositories for user braintree
# Fetched 68 repositories for user tollmanz
# Fetched 33 repositories for user tomschenkjr
# Fetched 79 repositories for user peterhurford
# Fetched 77 repositories for user kaihoffman
# Fetched 78 repositories for user stevenmaguire
# Fetched 262 repositories for user code-for-coffee
# Fetched 107 repositories for user joshgav
# Fetched 103 repositories for user zackkitzmiller
# Fetched 182 repositories for user southpolesteve
# Fetched 112 repositories for user kevinschaul
# Fetched 27 repositories for user ChrisWiegman
# Fetched 12 repositories for user jkocherhans
# Fetched 57 repositories for user mylo-james
# Fetched 500 repositories for user yyolk
# Fetched 87 repositories for user techtorial
# Fetched 19 repositories for user ch33r10
# Fetched 25 repositories for user feamster
# Fetched 31 repositories for user johnagan
# Fetched 48 repositories for user jeffpaul
# Fetched 51 repositories for user gregjopa
# Fetched 107 repositories for user argonne-lcf
# Fetched 26 repositories for user skriegman
# Fetched 38 repositories for user newville
# Fetched 243 repositories for user ryanve
# Fetched 94 repositories for user asajeffrey
# Fetched 47 repositories for user cooperlees
# Fetched 73 repositories for user dvtate
# Fetched 80 repositories for user deanmalmgren
# Fetched 118 repositories for user muratkeremozcan
# Fetched 17 repositories for user borjasotomayor
# Fetched 17 repositories for user ming024
# Fetched 21 repositories for user adamgraham
# Fetched 23 repositories for user nixpad
# Fetched 58 repositories for user cr0ybot
# Fetched 354 repositories for user karbassi
# Fetched 184 repositories for user gfredericks
# Fetched 80 repositories for user kfogel
# Fetched 19 repositories for user thereals0beit
# Fetched 14 repositories for user DataSolveProblems
# Fetched 346 repositories for user bangpound
# Fetched 90 repositories for user DebeshJha
# Fetched 15 repositories for user KazukiPrzyborowski
# Fetched 500 repositories for user marwahaha
# Fetched 19 repositories for user aerosoul94
# Fetched 55 repositories for user AgentK20
# Fetched 7 repositories for user safe-graph
# Fetched 25 repositories for user benstr
# Fetched 7 repositories for user relativityone
# Fetched 23 repositories for user monsur
# Fetched 421 repositories for user luisdomin5
# Fetched 105 repositories for user technobly
# Fetched 48 repositories for user JustinMShea
# Fetched 89 repositories for user Aeva
# Fetched 61 repositories for user adomokos
# Fetched 57 repositories for user spjeff
# Fetched 85 repositories for user klaeufer
# Fetched 7 repositories for user nicholas-ochoa
# Fetched 69 repositories for user arelia
# Fetched 140 repositories for user pyro2927
# Fetched 72 repositories for user Sc00bz
# Fetched 127 repositories for user wimglenn
# Fetched 82 repositories for user PedroLopes
# Fetched 98 repositories for user zekenie
# Fetched 28 repositories for user exrlla
# Fetched 36 repositories for user destefanis
# Fetched 248 repositories for user scollis
# Fetched 118 repositories for user joshbeckman
# Fetched 164 repositories for user carolineartz
# Fetched 28 repositories for user EricKuck
# Fetched 76 repositories for user michaelstonis
# Fetched 272 repositories for user datamade
# Fetched 165 repositories for user robertzk
# Fetched 30 repositories for user stephen-hoover
# Fetched 57 repositories for user baldengineer
# Fetched 86 repositories for user JeffCohen
# Fetched 20 repositories for user sc1341
# Fetched 87 repositories for user pcarbo
# Fetched 56 repositories for user gaojunxuan
# Fetched 56 repositories for user jim
# Fetched 4 repositories for user rathjenc
# Fetched 34 repositories for user jmercouris
# Fetched 227 repositories for user narcisolobo
# Fetched 31 repositories for user patrickfuller
# Fetched 73 repositories for user Interbotix
# Fetched 51 repositories for user donthedeveloper
# Fetched 129 repositories for user eigenhombre
# Fetched 28 repositories for user cdipaolo
# Fetched 116 repositories for user gkthiruvathukal
# Fetched 2 repositories for user zurmo
# Fetched 74 repositories for user Kaushal1011
# Fetched 139 repositories for user chicago-joe
# Fetched 140 repositories for user mqudsi
# Fetched 98 repositories for user rmw
# Fetched 86 repositories for user larsbergstrom
# Fetched 89 repositories for user azaa1
# Fetched 0 repositories for user allscriptshealthcare
# Fetched 43 repositories for user hugofloresgarcia
# Fetched 8 repositories for user abaker
# Fetched 64 repositories for user bitcraft
# Fetched 57 repositories for user glowcoil
# Fetched 39 repositories for user eguevara
# Fetched 57 repositories for user shanesveller
# Fetched 24 repositories for user curtgrimes
# Fetched 47 repositories for user SteveMcGrath
# Fetched 65 repositories for user rudyrigot
# Fetched 48 repositories for user seanwu1105
# Fetched 63 repositories for user NicholeKing
# Fetched 60 repositories for user bensoltoff
# Fetched 120 repositories for user blakesmith
# Fetched 44 repositories for user patrickxb
# Fetched 28 repositories for user Summair
# Fetched 138 repositories for user jvz
# Fetched 45 repositories for user gauss1181
# Fetched 12 repositories for user DavidJFelix
# Fetched 11 repositories for user chicagocomputerclasses
# Fetched 48 repositories for user gennyble
# Fetched 80 repositories for user y-x-c
# Fetched 45 repositories for user lukehoersten
# Fetched 84 repositories for user Chicago
# Fetched 36 repositories for user alainakafkes
# Fetched 40 repositories for user b-meson
# Fetched 33 repositories for user evbogue
# Fetched 11 repositories for user jwieting
# Fetched 212 repositories for user michel-slm
# Fetched 176 repositories for user piemadd
# Fetched 15 repositories for user rsinger86
# Fetched 87 repositories for user heitortsergent
# Fetched 25 repositories for user kvnkho
# Fetched 64 repositories for user christophermanning
# Fetched 58 repositories for user noelrappin
# Fetched 22 repositories for user ivanfemia
# Fetched 24 repositories for user SarahMAmann
# Fetched 83 repositories for user zircote
# Fetched 49 repositories for user sonamoo
# Fetched 22 repositories for user sleventyeleven
# Fetched 231 repositories for user coolreader18
# Fetched 38 repositories for user rossb34
# Fetched 5 repositories for user loucyx
# Fetched 65 repositories for user mgrygles
# Fetched 48 repositories for user alexlyp
# Fetched 59 repositories for user brianray
# Fetched 45 repositories for user skirmer
# Fetched 35 repositories for user agfor
# Fetched 112 repositories for user stamourv
# Fetched 48 repositories for user rsutphin
# Fetched 100 repositories for user barelyknown
# Fetched 30 repositories for user snowgy
# Fetched 405 repositories for user calchulus
# Fetched 26 repositories for user stevepopovich
# Fetched 78 repositories for user defaultxr
# Fetched 36 repositories for user andymboyle
# Fetched 117 repositories for user ksolo
# Fetched 10 repositories for user shonumi
# Fetched 53 repositories for user jdoss
# Fetched 21 repositories for user SpezialK71
# Fetched 248 repositories for user deanrad
# Fetched 9 repositories for user maggiewolff
# Fetched 7 repositories for user anthonyleezhang
# Fetched 10 repositories for user glitchfur
# Fetched 58 repositories for user daisyUniverse
# Fetched 63 repositories for user wmurphyrd
# Fetched 10 repositories for user KovasMcCann
# Fetched 23 repositories for user csantiago132
# Fetched 158 repositories for user CodyNicholson
# Fetched 49 repositories for user jaku
# Fetched 17 repositories for user AbrarSyed
# Fetched 198 repositories for user mgrover1
# Fetched 207 repositories for user maxmiller413
# Fetched 63 repositories for user juneau001
# Fetched 23 repositories for user CaryLandholt
# Fetched 65 repositories for user mstratman
# Fetched 50 repositories for user alycit
# Fetched 86 repositories for user knagaitsev
# Fetched 54 repositories for user omargfh
# Fetched 51 repositories for user RonaldColyar
# Fetched 21 repositories for user luoyuanlab
# Fetched 26 repositories for user jfnavarro21
# Fetched 6 repositories for user 3CloudSolutions
# Fetched 33 repositories for user rlk
# Fetched 336 repositories for user meltingscales
# Fetched 66 repositories for user scottferg
# Fetched 500 repositories for user erichilarysmithsr
#     login                full_name            created_at  stargazers_count  \
# 0  dabeaz             dabeaz/curio  2015-10-11T14:02:00Z              4036
# 1  dabeaz           dabeaz/scritch  2024-09-16T18:22:37Z                 1
# 2  dabeaz  dabeaz/python-distilled  2021-08-29T15:58:31Z                95
# 3  dabeaz              dabeaz/blog  2021-08-29T21:23:48Z               267
# 4  dabeaz               dabeaz/ply  2011-01-02T14:27:00Z              2790
#
#    watchers_count language  has_projects  has_wiki license_name
# 0            4036   Python          True      True        other
# 1               1     Java          True      True          NaN
# 2              95      NaN          True      True          NaN
# 3             267      NaN          True      True          NaN
# 4            2790   Python         False     False          NaN
#     login                full_name            created_at  stargazers_count  \
# 0  dabeaz             dabeaz/curio  2015-10-11T14:02:00Z              4036
# 1  dabeaz           dabeaz/scritch  2024-09-16T18:22:37Z                 1
# 2  dabeaz  dabeaz/python-distilled  2021-08-29T15:58:31Z                95
# 3  dabeaz              dabeaz/blog  2021-08-29T21:23:48Z               267
# 4  dabeaz               dabeaz/ply  2011-01-02T14:27:00Z              2790
#
#    watchers_count language has_projects has_wiki license_name
# 0            4036   Python         true     true        other
# 1               1     Java         true     true          NaN
# 2              95      NaN         true     true          NaN
# 3             267      NaN         true     true          NaN
# 4            2790   Python        false    false          NaN
# Saved 34870 repositories to repositories.csv

# %%
#2
import pandas as pd

# Load the users data from the CSV file
users_df = pd.read_csv("users.csv")

# Ensure that 'created_at' is in datetime format
users_df['created_at'] = pd.to_datetime(users_df['created_at'])

# Sort by 'created_at' in ascending order
sorted_users = users_df.sort_values(by='created_at', ascending=True)

# Select the first 5 users' 'login' values
earliest_users = sorted_users['login'].head(5).tolist()

# Join the logins into a comma-separated string
result = ", ".join(earliest_users)

print("Earliest registered users:", result)
# Out:
# Earliest registered users: ELLIOTTCABLE, trevorturk, lukehoersten, djspiewak, shanesveller

# %%
#3
import pandas as pd

# Load the repositories data from the CSV file
repos_df = pd.read_csv("repositories.csv")

# Filter out rows where 'license_name' is missing
filtered_repos = repos_df[repos_df['license_name'].notna()]

# Count occurrences of each license
license_counts = filtered_repos['license_name'].value_counts()

# Get the top 3 most popular licenses
top_licenses = license_counts.head(3).index.tolist()

# Join the licenses into a comma-separated string
result = ", ".join(top_licenses)

print("Top 3 most popular licenses:", result)
# Out:
# Top 3 most popular licenses: mit, other, apache-2.0

# %%
#4
import pandas as pd

# Load the users data from the CSV file
users_df = pd.read_csv("users.csv")

# Function to clean company names
def clean_company_name(name):
    if pd.isna(name):  # Handle missing values
        return ""
    name = name.strip()  # Trim whitespace
    if name.startswith("@"):
        name = name[1:]  # Remove leading '@'
    return name.upper()  # Convert to uppercase

# Apply the cleaning function to the 'company' column
users_df['company'] = users_df['company'].apply(clean_company_name)

# Filter out empty company entries
filtered_companies = users_df[users_df['company'] != ""]

# Count occurrences of each company
company_counts = filtered_companies['company'].value_counts()

# Identify the company with the highest count
most_common_company = company_counts.idxmax()

print("Company with the majority of developers:", most_common_company)
# Out:
# Company with the majority of developers: UNIVERSITY OF CHICAGO

# %%
#5
import pandas as pd

# Load the repositories data
repos_df = pd.read_csv("repositories.csv")

# Filter out rows where the language is missing
filtered_languages = repos_df[repos_df['language'].notna()]

# Count occurrences of each language
language_counts = filtered_languages['language'].value_counts()

# Get the most popular language
most_popular_language = language_counts.idxmax()

print("Most popular programming language:", most_popular_language)
# Out:
# Most popular programming language: JavaScript

# %%
#6
import pandas as pd

# Load the data
users_df = pd.read_csv("users.csv")
repos_df = pd.read_csv("repositories.csv")

# Convert 'created_at' to datetime format and filter users who joined after 2020
users_df['created_at'] = pd.to_datetime(users_df['created_at'])
recent_users = users_df[users_df['created_at'] > '2020-01-01']

# Filter repositories for these users
filtered_repos = repos_df[repos_df['login'].isin(recent_users['login'])]

# Count occurrences of each language, ignoring missing languages
language_counts = filtered_repos['language'].dropna().value_counts()

# Get the second most popular language
second_most_popular_language = language_counts.index[1] if len(language_counts) > 1 else None

print("Second most popular programming language among users who joined after 2020:", second_most_popular_language)
# Out:
# Second most popular programming language among users who joined after 2020: JavaScript

# %%
#7
import pandas as pd

# Load the repositories data
repos_df = pd.read_csv("repositories.csv")

# Filter out rows with missing language or stargazers_count values
repos_df = repos_df.dropna(subset=['language', 'stargazers_count'])

# Group by language and calculate the average number of stars per repository
avg_stars_per_language = repos_df.groupby('language')['stargazers_count'].mean()

# Find the language with the highest average stars
most_popular_language = avg_stars_per_language.idxmax()
highest_avg_stars = avg_stars_per_language.max()

print("Language with the highest average stars per repository:", most_popular_language)
print("Average stars:", round(highest_avg_stars, 3))
# Out:
# Language with the highest average stars per repository: Vim Script
# Average stars: 647.682

# %%
#8
import pandas as pd

# Load the users data
users_df = pd.read_csv('users.csv')

# Calculate leader_strength
users_df['leader_strength'] = users_df['followers'] / (1 + users_df['following'])

# Sort by leader_strength in descending order and select the top 5 users
top_5_leaders = users_df.sort_values(by='leader_strength', ascending=False).head(5)

# Print the top 5 users' logins as a comma-separated string
top_5_logins = ", ".join(top_5_leaders['login'])
print(f"Top 5 users in terms of leader_strength: {top_5_logins}")
# Out:
# Top 5 users in terms of leader_strength: dabeaz, sstephenson, khan4019, adashofdata, djspiewak

# %%
#9
import pandas as pd

# Load the users data
users_df = pd.read_csv('users.csv')

# Filter for users in Chicago
chicago_users = users_df[users_df['location'].str.contains('Chicago', case=False, na=False)]

# Calculate the correlation between followers and public repositories
correlation = chicago_users['followers'].corr(chicago_users['public_repos'])

# Print the correlation rounded to 3 decimal places
print(f"Correlation between followers and public repositories: {correlation:.3f}")
# Out:
# Correlation between followers and public repositories: 0.077

# %%
#10
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np

# Load the users data
users_df = pd.read_csv('users.csv')

# Filter for users in Chicago (if required)
chicago_users = users_df[users_df['location'].str.contains('Chicago', case=False, na=False)]

# Reshape the data for sklearn's LinearRegression
X = chicago_users['public_repos'].values.reshape(-1, 1)
y = chicago_users['followers'].values

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Get the regression slope (followers per additional public repository)
slope = model.coef_[0]

# Print the slope rounded to 3 decimal places
print(f"Regression slope of followers on repos: {slope:.3f}")
# Out:
# Regression slope of followers on repos: 0.617

# %%
#11
import pandas as pd

# Load the repositories data
repositories_df = pd.read_csv('repositories.csv')

# Convert boolean columns to integers for correlation calculation
repositories_df['has_projects'] = repositories_df['has_projects'].astype(int)
repositories_df['has_wiki'] = repositories_df['has_wiki'].astype(int)

# Calculate the correlation between projects and wiki enabled
correlation = repositories_df['has_projects'].corr(repositories_df['has_wiki'])

# Print the correlation rounded to 3 decimal places
print(f"Correlation between projects and wiki enabled: {correlation:.3f}")
# Out:
# Correlation between projects and wiki enabled: 0.288

# %%
#12
import pandas as pd

def analyze_following_difference(users_csv_path='users.csv'):
    # Read the data
    df = pd.read_csv(users_csv_path)

    # Calculate average following for hireable users
    hireable_following = df[df['hireable'] == True]['following'].mean()

    # Calculate average following for non-hireable users
    non_hireable_following = df[df['hireable'] != True]['following'].mean()

    # Calculate the difference rounded to 3 decimal places
    difference = round(hireable_following - non_hireable_following, 3)

    # Print debug information
    print(f"Number of hireable users: {len(df[df['hireable'] == True])}")
    print(f"Number of non-hireable users: {len(df[df['hireable'] != True])}")
    print(f"Average following for hireable users: {hireable_following:.3f}")
    print(f"Average following for non-hireable users: {non_hireable_following:.3f}")

    return difference

# Calculate the difference
result = analyze_following_difference()
print(f"\nDifference in average following: {result:.3f}")
# Out:
# Number of hireable users: 94
# Number of non-hireable users: 282
# Average following for hireable users: 214.936
# Average following for non-hireable users: 103.248
#
# Difference in average following: 111.688

# %%
#13
import pandas as pd
import statsmodels.api as sm

def analyze_bio_impact(users_csv_path='users.csv'):
    # Read the data
    df = pd.read_csv(users_csv_path)

    # Filter out users without bios
    df = df[df['bio'].notna()]

    # Calculate the length of each bio in words
    df['bio_word_count'] = df['bio'].apply(lambda x: len(x.split()))

    # Define the dependent and independent variables
    X = df['bio_word_count']  # Independent variable
    y = df['followers']        # Dependent variable

    # Add a constant to the independent variable for the regression model
    X = sm.add_constant(X)

    # Fit the regression model
    model = sm.OLS(y, X).fit()

    # Get the slope (coefficient for bio_word_count)
    slope = model.params['bio_word_count']

    return round(slope, 3)

# Calculate the regression slope
slope_result = analyze_bio_impact()
print(f"Regression slope of followers on bio word count: {slope_result:.3f}")
# Out:
# Regression slope of followers on bio word count: 3.047

# %%
#14
import pandas as pd

def top_weekend_repository_creators(users_csv_path='repositories.csv'):
    # Read the repositories data
    df = pd.read_csv(users_csv_path)

    # Convert 'created_at' to datetime
    df['created_at'] = pd.to_datetime(df['created_at'])

    # Filter for weekend days (Saturday and Sunday)
    weekend_repos = df[df['created_at'].dt.dayofweek >= 5]

    # Count repositories created by each user
    top_users = weekend_repos['login'].value_counts().head(5)

    # Get the top 5 users' logins in order
    return ', '.join(top_users.index)

# Get the top users
top_users_logins = top_weekend_repository_creators()
print(f"Top 5 users who created the most repositories on weekends: {top_users_logins}")
# Out:
# Top 5 users who created the most repositories on weekends: marwahaha, eddelbuettel, sabre1041, erichilarysmithsr, yyolk

# %%
#15
import pandas as pd

def analyze_email_sharing(users_csv_path='users.csv'):
    # Read the data
    df = pd.read_csv(users_csv_path)

    # Calculate the total number of hireable users and those with email addresses
    hireable_total = df[df['hireable'] == True].shape[0]
    hireable_with_email = df[(df['hireable'] == True) & (df['email'].notna())].shape[0]

    # Calculate the total number of non-hireable users and those with email addresses
    non_hireable_total = df[df['hireable'] != True].shape[0]
    non_hireable_with_email = df[(df['hireable'] != True) & (df['email'].notna())].shape[0]

    # Calculate fractions
    hireable_email_fraction = hireable_with_email / hireable_total if hireable_total > 0 else 0
    non_hireable_email_fraction = non_hireable_with_email / non_hireable_total if non_hireable_total > 0 else 0

    # Calculate the difference rounded to 3 decimal places
    difference = round(hireable_email_fraction - non_hireable_email_fraction, 3)

    return difference

# Calculate the difference in email sharing
email_sharing_difference = analyze_email_sharing()
print(f"Difference in email sharing: {email_sharing_difference:.3f}")
# Out:
# Difference in email sharing: 0.060

# %%
#16
import pandas as pd

# Load the users data from the CSV file
users_df = pd.read_csv("users.csv")

# Filter out rows with missing names
names_with_surnames = users_df.dropna(subset=['name'])

# Extract the last word in each name as the surname
names_with_surnames['surname'] = names_with_surnames['name'].apply(lambda x: x.strip().split()[-1])

# Count the frequency of each surname
surname_counts = names_with_surnames['surname'].value_counts()

# Find the maximum count
max_count = surname_counts.max()

# Get all surnames with the maximum count
most_common_surnames = surname_counts[surname_counts == max_count].index.tolist()

# Sort the surnames alphabetically if there are ties
most_common_surnames.sort()

# Join the surnames in a comma-separated string
result = ", ".join(most_common_surnames)

print("Most common surname(s):", result)
# Out:
# Most common surname(s): Smith
# <ipython-input-2-c0444d2f2047>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   names_with_surnames['surname'] = names_with_surnames['name'].apply(lambda x: x.strip().split()[-1])
